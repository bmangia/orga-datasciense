# %%
from pyspark.mllib.feature import HashingTF, IDF
from pyspark.mllib.regression import LabeledPoint
from pyspark.mllib.classification import NaiveBayes   
import pyspark

try: 
    type(sc)
except NameError:
    sc = pyspark.SparkContext('local[*]') 
    
training_raw = sc.textFile('data/train.csv')


# Split data into labels and features, transform
# preservesPartitioning is not really required
# since map without partitioner shouldn't trigger 
print("Extraxendo predicciones...")
labels = training_raw.map(
    lambda doc: doc["Prediction"],  # Standard Python dict access 
    preservesPartitioning=True # This is obsolete.
)
print("OK\n")

print("Hasheando palabras...")
tf = HashingTF(numFeatures=100).transform(training_raw.map(lambda doc: doc["Text"].split(), preservesPartitioning=True))
print("OK\n")

idf = IDF().fit(tf)
tfidf = idf.transform(tf)

# Combine using zip
print("Combining using zip(?)...")
training = labels.zip(tfidf).map(lambda x: LabeledPoint(x[0], x[1]))
print("OK\n")

# Train and check
print("Trainning...")
model = NaiveBayes.train(training)
print("OK\n")

labels_and_preds = labels.zip(model.predict(tfidf)).map(lambda x: {"actual": x[0], "predicted": float(x[1])})
# Out:
# Extraxendo predicciones...
# OK
#
# Hasheando palabras...
# OK
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-11-6b74a02c5fa9> in <module>()
#      26 print("OK\n")
#      27
# ---> 28 idf = IDF().fit(tf)
#      29 tfidf = idf.transform(tf)
#      30
#
# /usr/local/spark/python/pyspark/mllib/feature.py in fit(self, dataset)
#     447         if not isinstance(dataset, RDD):
#     448             raise TypeError("dataset should be an RDD of term frequency vectors")
# --> 449         jmodel = callMLlibFunc("fitIDF", self.minDocFreq, dataset.map(_convert_to_vector))
#     450         return IDFModel(jmodel)
#     451
#
# /usr/local/spark/python/pyspark/mllib/common.py in callMLlibFunc(name, *args)
#     128     sc = SparkContext.getOrCreate()
#     129     api = getattr(sc._jvm.PythonMLLibAPI(), name)
# --> 130     return callJavaFunc(sc, api, *args)
#     131
# ...
