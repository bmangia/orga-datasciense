# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib
matplotlib.rcParams['agg.path.chunksize'] = 10000

data_train = pd.read_csv("data/train.csv", sep=',',encoding='latin1', parse_dates=['Time'], dayfirst=True, index_col='Id')
data_test = pd.read_csv("data/test.csv")

data_train.head()
# Out:
#          ProductId          UserId                ProfileName  \
# Id
# 492346  B001VNP0Y6   AEZRVY3CV52UZ  Corey Wright "Democratus"
# 343811  B008J1HO4C  A18VZYSLOUO060    D. Simpson "Frugal SOB"
# 347257  B000FFIL60  A28Y1M7GRG0I9M        Real Comments "Lin"
# 225529  B002ZX1U9A  A245HC4T5J97WG            Logan DeAngelis
# 485488  B001RVFERK   AVABPJCKE2MR5                       spal
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Prediction        Time  \
# Id
# 492346                     3                       3           5  1320537600
# 343811                     2                       2           5  1204329600
# 347257                     0                       0           4  1318464000
# 225529                     0                       0           5  1306540800
# 485488                     0                       0           4  1314921600
#
#                               Summary  \
# Id
# 492346             Just what I needed
# 343811         Most excellent oatmeal
# 347257                    Quality Tea
# 225529  Great Coffee at a Great price
# 485488       Popchips Jalapeno flavor
#
#                                                      Text
# Id
# 492346  I got them in a very timely manner and they're...
# 343811  McCann's Steel Cut Oatmeal is the perfect brea...
# 347257  I would recommend it. Quality pearls and a few...
# 225529  I have to admit, I first purchased these Hazel...
# 485488  I bought a case of jalapeno chips as I love th...

# %%
data_train.describe()
# Out:
#          ProductId          UserId  \
# Id
# 492346  B001VNP0Y6   AEZRVY3CV52UZ
# 343811  B008J1HO4C  A18VZYSLOUO060
# 347257  B000FFIL60  A28Y1M7GRG0I9M
# 225529  B002ZX1U9A  A245HC4T5J97WG
# 485488  B001RVFERK   AVABPJCKE2MR5
# 74981   B0026RQTGE  A161Y9NAR43WCW
# 204180  B000F0FZE6  A1H35JZ9UUCVIF
# 454372  B0019K981W  A13H71301WENPW
# 112235  B0009JJB4S  A2HBOYLMGW2A5Y
# 295251  B000LQNK50   ATO0RF3HWQ3WW
# 2544    B000G7UDPY  A392JXFKJ5GG17
# 435949  B0016COPSY   A6KL17KKN0A5L
# 179209  B000V1FI5U  A2DQ0KE7NH5A08
# 243805  B001LQNVOE  A3JJOUVMIIXLFQ
# 11688   B0032RPLSY  A2ELBN89JT1S4T
# 459662  B000LKTJUG  A3PNHHF9XWHJGR
# 525701  B0015V1WMS  A3BTGGLX2B6Q6N
# 31901   B0062A87HA   ACVLAI219S7TT
# 135696  B003THML30  A1RC6AKHUZKRQS
# 16179   B0001BVD04  A2YDEO5BR1OA5R
# 79185   B002WDCIXK  A336LGWA4H3V4H
# 178788  B0001WAMA0  A2HTHVCM8MEM3F
# 450065  B001SB6A7C  A2GOR08W4UGJO7
# 340470  B002ITIBQG   AKB3TXWM102DR
# 409742  B003LPZTTS  A2V8GTSHVKMFI3
# 302044  B0048CHI9M    AUUFW7PTUHLT
# 231195  B003FDC2I2  A2IZEN3G4J0605
# 391725  B000YQCDQY  A3F34JZEKQBH68
# 549077  B000WV153I  A27AB7VV7ETZ74
# 448115  B001FXU6QO   AKGIHE73N0HJW
# ...            ...             ...
# 492362  B0000GHNWM  A3S583K80QN1VG
# 380026  B0000GGQ9S  A3AUIBGC4GBJRN
# 197735  B001KUQIU0  A2DMNKPJ66FGSF
# 214343  B0071NOCZI  A2GMHIR0IO17MC
# 215678  B0000DGFA9   AY5ZSPFV0KU9S
# 422164  B001M0ALII   A4HYBNLBZQKT4
# 170157  B002ZOG29C  A3QCB5B9MJDFE0
# 103095  B001E5E2RM  A1H2HWIKE54BW2
# 513244  B0042GWKWO  A399CPNJQRTGZB
# 566838  B001PQTYN2   AIZ6SVHMW2W08
# 27744   B0000VLRCY  A2HCE1UR9PSLWI
# 325701  B001QXZ0UA  A2OU28VMJMCEVQ
# 196338  B0014EUA74  A1QBP9ENAWJJMG
# 419592  B0029ZAOW8  A1A3UOWBF5O7DI
# 355625  B002QWP8H0  A277AIYW087GSU
# 158429  B000BF3AL0  A3GMYLZ3OGQUA2
# 281839  B000MT4HWG  A1VY1F9DAM2ZSJ
# 194327  B002HFLHEE  A2MOJANFPX353G
# 56659   B0012XBD7I  A2JFHMA59G55MJ
# 530750  B0014ATRV8  A17AQQD8K5WB63
# 377098  B000JJHDVG  A175P02JGBC59A
# 556672  B000H0ZJHW  A1UL64AZIAO2EC
# 159637  B001O2HB78  A31HE83MU98GBV
# 317645  B001EO6FO6  A34IGZ989XN4ZH
# 426070  B000TQEWM2   AJSN7I5XOXXM5
# 74384   B001BM3C0Q  A3B4T4YD12U1R8
# 100692  B002N7DSLG  A2C0SYDL7YZGMX
# 380375  B00112CND8  A14DR2RP5PAKNS
# 377102  B000JJHDVG  A3VI3YVT2IGF0D
# 306406  B000VK6TKO  A38Z30KAT7J1PS
#
#                                            ProfileName  HelpfulnessNumerator  \
# Id
# 492346                       Corey Wright "Democratus"                     3
# 343811                         D. Simpson "Frugal SOB"                     2
# 347257                             Real Comments "Lin"                     0
# 225529                                 Logan DeAngelis                     0
# 485488                                            spal                     0
# 74981                                           vertov                     0
# 204180                                        carrera4                     1
# 454372                          Patricia Fentriss "PF"                    11
# 112235                                             lee                     0
# 295251                                 Scott "Scottso"                    12
# 2544                                  Donna G. Spencer                     0
# 435949                                       K. Harper                    14
# 179209                          Alice McDaniel "Alice"                     0
# 243805                                       L  Willis                     0
# 11688                                         Maybelle                     0
# 459662                             Kyle Smeby "kyle78"                     1
# 525701                                          sponse                     0
# 31901                                      Wendy in Pa                    12
# 135696                                             Amy                     0
# 16179                                            Pelly                     5
# 79185                                          Blarney                     1
# 178788  Nikijay88 "Always hoping for happiness &#60;3"                     2
# 450065                                    austinwriter                     0
# 340470                             Rebecca "red roots"                     0
# 409742                                   Z. "speedyZ."                     1
# 302044                                      MamaSylvia                     0
# 231195                                       Ultraquel                     1
# 391725                                  Karen Canellos                     0
# 549077                                     Danielle O.                     3
# 448115                                        jennifer                     0
# ...                                                ...                   ...
# 492362                  G. M. Handlon "the brewfisher"                    19
# 380026                                  Marvin Gardens                    15
# 197735                                 Velda L. Truitt                     3
# 214343                                         sakyurt                     1
# 215678                                  Ralf Rashbrook                     2
# 422164                                           D. Ma                     0
# 170157                                          Teresa                     2
# 103095                                    Lorena Ferro                     0
# 513244                                         J. Seab                     4
# 566838                                        peekaboy                     0
# 27744                        CarolMC "Philippians 4:8"                     1
# 325701                                       K. Wilson                     5
# 196338         Bobby Duff "Devastatingly Handsome Man"                     0
# 419592                             Alexander The Great                     0
# 355625                                             Ram                     0
# 158429                                    Diane Kalata                     1
# 281839                                 dabird "dabird"                     0
# 194327                                           Ken M                     8
# 56659                                        MisterJym                     2
# 530750                                          sss147                     5
# 377098                                   Missouri Beth                     1
# 556672                    Karen Malandruccolo "LuvMax"                     0
# 159637                                     Gadget Girl                     0
# 317645                                     Isa H. Loeb                     2
# 426070                                         Sanibel                     1
# 74384                                    Tropical girl                     0
# 100692             Teresa M. Cook "gluten-free patron"                     1
# 380375                                           Laura                     1
# 377102                                      allergymom                     1
# 306406                                  yojimko "Alex"                     2
#
#         HelpfulnessDenominator  Prediction        Time  \
# Id
# 492346                       3           5  1320537600
# 343811                       2           5  1204329600
# 347257                       0           4  1318464000
# 225529                       0           5  1306540800
# 485488                       0           4  1314921600
# 74981                        0           5  1314835200
# 204180                       1           5  1330646400
# 454372                      13           1  1249344000
# 112235                       0           5  1345852800
# 295251                      16           3  1236729600
# 2544                         1           1  1266019200
# 435949                      20           4  1291593600
# 179209                       0           3  1339977600
# 243805                       1           5  1335657600
# 11688                        0           5  1351123200
# 459662                       1           5  1233878400
# 525701                       0           4  1290988800
# 31901                       12           1  1279670400
# 135696                       0           1  1339718400
# 16179                        5           4  1150329600
# 79185                        1           2  1326412800
# 178788                       2           5  1329350400
# 450065                       1           4  1331510400
# 340470                       0           5  1319760000
# 409742                       1           3  1311811200
# 302044                       0           5  1338163200
# 231195                       1           5  1287964800
# 391725                       0           5  1346630400
# 549077                       3           5  1337212800
# 448115                       0           5  1301875200
# ...                        ...         ...         ...
# 492362                      21           5  1170374400
# 380026                      15           5  1162857600
# 197735                       3           5  1288396800
# 214343                       2           1  1349481600
# 215678                       4           3  1202515200
# 422164                       0           3  1350000000
# 170157                       2           3  1335830400
# 103095                       0           5  1342828800
# 513244                       6           2  1125792000
# 566838                       0           5  1344038400
# 27744                        1           5  1328227200
# 325701                       5           5  1306972800
# 196338                       0           4  1334620800
# 419592                       0           5  1312934400
# 355625                       0           5  1344556800
# 158429                       1           5  1233273600
# 281839                       0           5  1337299200
# 194327                       8           5  1214870400
# 56659                        2           5  1329091200
# 530750                       6           5  1318464000
# 377098                       1           5  1332374400
# 556672                       0           5  1334534400
# 159637                       0           5  1271376000
# 317645                       2           5  1301788800
# 426070                       1           5  1306108800
# 74384                        0           4  1263686400
# 100692                       1           5  1189987200
# 380375                       4           2  1346544000
# 377102                       1           5  1316995200
# 306406                       3           1  1261267200
#
#                                                   Summary  \
# Id
# 492346                                 Just what I needed
# 343811                             Most excellent oatmeal
# 347257                                        Quality Tea
# 225529                      Great Coffee at a Great price
# 485488                           Popchips Jalapeno flavor
# 74981                            Our dog has fresh breath
# 204180                             Great Pasta & Healthy!
# 454372  Sugar bomb!!!  Same amount of sugar as a 12 oz...
# 112235                        Pretty great for the price!
# 295251                                             Its OK
# 2544                                     Bad tasting soup
# 435949         I like it, but it's a product of Taiwan...
# 179209  Okay but learning that I'm just not into "flav...
# 243805                          This is very good coffee.
# 11688                                          Delicious!
# 459662                              Cure for sore throats
# 525701                Gold coins were a great party favor
# 31901   Is someone using Amazon as an outlet for dente...
# 135696                                Don't buy from here
# 16179                             Cheaper in supermarkets
# 79185                                   Way too expensive
# 178788                           Great Appreciation Gift!
# 450065                            Great Taste, Small Bags
# 340470                      TRY THESE, THEY'RE DELICIOUS!
# 409742                                 With pros and cons
# 302044                                  Sugar-free to go!
# 231195                                             Great!
# 391725                                good tasting flavor
# 549077           Simply the best food I've ever consumed.
# 448115                 Love this product works amazing!!!
# ...                                                   ...
# 492362                     A *must-have* household staple
# 380026                   Herdez chipotles beat all others
# 197735                                     Great Product!
# 214343            Atkinsons Sugar Free Peanut Butter Bars
# 215678                             Nice plant but no tray
# 422164        okay product, not good packaging all dented
# 170157                                         Good value
# 103095                              exactly ehat i wanted
# 513244                                             Ho hum
# 566838                                   fantastic sauce!
# 27744                                    Fantastic Flavor
# 325701                        Dry Roasted Eden Pistachios
# 196338                                 Excellent Product.
# 419592  Great Product - Fast Shipping and Cheap Unit P...
# 355625  My dog loves them and the Vet complimented my ...
# 158429                                         veja-links
# 281839                         My dog loves these things!
# 194327                          Excellent Tea, Good Price
# 56659           Favorite Kettle flavor and a great value!
# 530750                                          delicious
# 377098                               absolutely delicious
# 556672                                My dog says "Yummy"
# 159637                                      Great flavor!
# 317645                               Great strong coffee!
# 426070                              Great Flavored Coffee
# 74384                         Thin & crispy but too salty
# 100692                               Lemon Glutino wafers
# 380375                                  Not as advertised
# 377102                          Great Product Great Price
# 306406                     sitting on the shelf too long.
#
#                                                      Text
# Id
# 492346  I got them in a very timely manner and they're...
# 343811  McCann's Steel Cut Oatmeal is the perfect brea...
# 347257  I would recommend it. Quality pearls and a few...
# 225529  I have to admit, I first purchased these Hazel...
# 485488  I bought a case of jalapeno chips as I love th...
# 74981   No doggie breath for our dog.  People are alwa...
# 204180  I tried this pasta after viewing the Dr. Oz sh...
# 454372  Check out the sugar content before you buy!  2...
# 112235  I drink Iron goddess oolong pretty often, it i...
# 295251  Maybe it's due to my tendency to prefer noodle...
# 2544    This is one of the worse tasting soups I've ev...
# 435949  While I love the product, if you read the labe...
# 179209  I ordered these and was excited about them.  T...
# 243805  We like our coffee strong but not bitter. This...
# 11688   This ghee is delicious. A little goes a long w...
# 459662  For about 5 years, especially during the winte...
# 525701  This product was perfect for a volunteer recog...
# 31901   I received Farmers Market Organic Pumpkin 12 p...
# 135696  I was expecting two packs of these like the de...
# 16179   This is a great fruit soda, will surprise you ...
# 79185   Like the product, but come on....  $38.00 for ...
# 178788  I sent this to my mother as a thank you for al...
# 450065  The taste of these chips is incredible. My onl...
# 340470  You have to treat yourself to these wonderful ...
# 409742  Pros:<br />1. Clumps well.<br />2. Easy to get...
# 302044  I always keep one of these in my purse because...
# 231195  Orgain is healthier than most drinks, so it sa...
# 391725  If you are trying to watch calories, these are...
# 549077  I can't stop eating this stuff! The taste is s...
# 448115  I love this product, first it was supose to ge...
# ...                                                   ...
# 492362  This sauce is medium heat for everyday use.  I...
# 380026  Canned chipotles are smoked, pickled jalapeno ...
# 197735  This is a great product, and just what I had b...
# 214343  We're not likely to buy this if you don't even...
# 215678  The bonsai is a nice plant, and it did arrive ...
# 422164  I bought this to make vietnamese coffee. It ta...
# 170157  This product is a good value for the money; co...
# 103095  I love the flavor of this product and the best...
# 513244  Nothing particulary outstanding about this cho...
# 566838  There are plenty of reviews about this sauce t...
# 27744   Great flavor, much stronger flavor than an ext...
# 325701  Great product....like the little sealed bag......
# 196338  Packed with sausage and creamy smooth gravy th...
# 419592  This was a great order.  The unit price was ri...
# 355625  Started buying these for my dog and he loves t...
# 158429  We discovered Veja-links while we were doing a...
# 281839  I got these from my local pet store, where the...
# 194327  I started loving Oolong tea after I discovered...
# 56659   After reading some of the reviews, I got nervo...
# 530750  This tea is great.  I cook it in gallon batche...
# 377098  I don't really care for maple syrup, but maple...
# 556672  My dog absolutely loves these treats.  Sometim...
# 159637  This is our six month's old favorite baby food...
# 317645  I really like this coffee. It has a nice flavo...
# 426070  If you enjoy Hazlenut coffee this one is for y...
# 74384   I love blue corn tortillas and their products....
# 100692  These wafer cookies are every bit as good as t...
# 380375  I have a few gluten free bread cookbooks. My c...
# 377102  I have tried several maple sugar products in t...
# 306406  This was not a "fresh" product.  My cats (nine...
#
# [454760 rows x 9 columns]

# %%
prediction_0 = data_train[data_train['Prediction']==0]['Prediction'].value_counts()
prediction_1 = data_train[data_train['Prediction']==1]['Prediction'].value_counts()
prediction_2 = data_train[data_train['Prediction']==2]['Prediction'].value_counts()
prediction_3 = data_train[data_train['Prediction']==3]['Prediction'].value_counts()
prediction_4 = data_train[data_train['Prediction']==4]['Prediction'].value_counts()
prediction_5 = data_train[data_train['Prediction']==5]['Prediction'].value_counts()

df = pd.DataFrame([prediction_0,prediction_1,prediction_2,prediction_3,prediction_4,prediction_5])
df.index = ['0','1','2','3','4','5']
df.plot(kind='bar',stacked=True, figsize=(7,5))

# %%
plt.figure(figsize=(18,8))

ax = plt.subplot(121)
ax.scatter(data_train[data_train['Prediction']==1]['Prediction'],data_train[data_train['Prediction']==1]['HelpfulnessNumerator'],c='green',s=40)
ax.scatter(data_train[data_train['Prediction']==2]['Prediction'],data_train[data_train['Prediction']==2]['HelpfulnessNumerator'],c='red',s=40)
ax.scatter(data_train[data_train['Prediction']==3]['Prediction'],data_train[data_train['Prediction']==3]['HelpfulnessNumerator'],c='orange',s=40)
ax.scatter(data_train[data_train['Prediction']==4]['Prediction'],data_train[data_train['Prediction']==4]['HelpfulnessNumerator'],c='brown',s=40)
ax.scatter(data_train[data_train['Prediction']==5]['Prediction'],data_train[data_train['Prediction']==5]['HelpfulnessNumerator'],c='yellow',s=40)
ax.set_xlabel('Prediccion')
ax.set_ylabel('HelpfulnessNumerator')
ax.legend(('1','2','3','4','5'),scatterpoints=1,loc='upper right',fontsize=15,)

ax1 = plt.subplot(122)
ax1.scatter(data_train[data_train['Prediction']==1]['Prediction'],data_train[data_train['Prediction']==1]['HelpfulnessDenominator'],c='green',s=40)
ax1.scatter(data_train[data_train['Prediction']==2]['Prediction'],data_train[data_train['Prediction']==2]['HelpfulnessDenominator'],c='red',s=40)
ax1.scatter(data_train[data_train['Prediction']==3]['Prediction'],data_train[data_train['Prediction']==3]['HelpfulnessDenominator'],c='orange',s=40)
ax1.scatter(data_train[data_train['Prediction']==4]['Prediction'],data_train[data_train['Prediction']==4]['HelpfulnessDenominator'],c='brown',s=40)
ax1.scatter(data_train[data_train['Prediction']==5]['Prediction'],data_train[data_train['Prediction']==5]['HelpfulnessDenominator'],c='yellow',s=40)
ax1.set_xlabel('Prediccion')
ax1.set_ylabel('HelpfulnessDenominator')
ax1.legend(('1','2','3','4','5'),scatterpoints=1,loc='upper right',fontsize=15,)

# %%
plt.figure(figsize=(18,8))
hn = plt.subplot()
hn.plot(data_train['Time'],data_train['HelpfulnessDenominator'])
hn.plot(data_train['Time'],data_train['HelpfulnessNumerator'])
